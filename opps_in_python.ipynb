# %%
## creating class
class Student:
    name = "ranjesh"
## creating object
s1 = Student()
print(s1.name)
# Out:
# ranjesh

# %%
class Car:
  color = "blue" ## blueprint in class
  model = "2000"

car1 = Car()
print(car1.color)
print(car1.model)
# Out:
# blue
# 2000

# %%
class Student:
    college_name = "MIT"


    def __init__(self): ## default constructer
        self.name = "ranjesh"


    def __init__(self, name,marks): ## parameterized constructer
        self.name = name
        self.marks = marks


s1 = Student("ranjesh",95) ## first object
print(s1.name, s1.marks)

s2 = Student("arjun",43)   ## second object
print(s2.name, s2.marks)


print(s2.college_name) or print(Student.college_name)

 ## Here name and marks are  instantce attributes and college_name is class attributes
# Out:
# ranjesh 95
# arjun 43
# MIT
# MIT

# %%
## METHOD

class Student:
    college_name = "MIT"

    def __init__(self, name,marks): ## parameterized constructer
        self.name = name
        self.marks = marks

    def welcome(self)  : # this is method
      print("welcome students ,",self.name)

    def get_marks(self): ## this is method
      return self.marks

s1 = Student("ranjesh",94)
s1.welcome()
print(s1.get_marks())
# Out:
# welcome students , ranjesh
# 94

# %% [markdown]
# **Practice question:
#     Create student class that takes name and marks of 3 subjects as
#     arguments in constructor. Then create a method to print average**

# %%
class Student:


    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def avg_marks(self): # de-indent this method
        sum = 0
        for i in self.marks:
            sum = sum + i

        print("hii", self.name,"your average marks is",sum/3) # Fix: len(self.marks)

s1 = Student("ranjesh",[94,95,96])
s1.avg_marks()
# Out:
# hii ranjesh your average marks is 95.0

# %%
##Static Method

class Student:
    @staticmethod
    def college():
      print("my coolage")

# %% [markdown]
# **ABSTRACTION
#         :  Hiding the implementation details of a class
#            and only showing the essential feature to the user**

# %%
class Car:
  def __init__(self):
    self.acc = False
    self.brk = False
    self.clutch = False
    self.speed = 0
  def start(self):
    self.clutch = True
    self.acc = True
    print("Car started")

s1 = Car()
s1.start()
# Out:
# Car started

# %% [markdown]
# **ENCAPSULATION:
#                  Wraping data and functions into a single unit(objects)**

# %% [markdown]
# *Practice problem:
#        Create Account class with 2 attributes balance and account nu.
#        Create method for debit , credit and printing the balance*

# %%
class Account:
  def __init__(self,account_no,balance):
    self.account_no = account_no
    self.balance = balance

    ##  debit metohd
  def debit(self,amount):
    self.balance = self.balance - amount
    print("Rs.", amount,"was debited")
    print("total balance = ", self.get_balance())

  def credit(self,amount):
    self.balance += amount
    print("Rs.",amount,"was credited")
    print("total balance=",self.get_balance())

  def get_balance(self):
    return self.balance




acc1 = Account(12345, 30000)
acc1.debit(1000)
acc1.credit(2000)
acc1.credit(2030)
acc1.debit(100)
# Out:
# Rs. 1000 was debited
# total balance =  29000
# Rs. 2000 was credited
# total balance= 31000
# Rs. 2030 was credited
# total balance= 33030
# Rs. 100 was debited
# total balance =  32930

# %%
## del keyword
## used to delete object properties or object itself


class Student:
  def __init__(self,name):
    self.name = name
s1 = Student("ranjesh")

del s1.name
print(s1.name)


### AttributeError: 'Student' object has no attribute 'name', afther running above showing this
# Out:
# ranjesh
# ...

# %% [markdown]
# **If we want to do private the attributes and methods then we need to write the
#  __ or double underscore before the arrtibutes and methods**

# %%
class Person:
  __name = "ranjesh"

  def __hello():
    print("hello")

p1 = Person()
print(p1.__name)
print(p1.__hello())

## Above print will be give the error

# %% [markdown]
# **Inheritance:
#
#              When one class(child/derived) derives the prperties and method
#              of another class(parent/base) is called Inheritance**

# %% [markdown]
# **Single Inheritance**

# %%
class Car():

  color = "blue"
  model = "2000"
  @staticmethod
  def start():
    print("car start..")

  @staticmethod
  def stop():
    print("car stoped.")


class ToyotaCar(Car):

  def __init__(self,name):
    self.name = name


c1 = ToyotaCar("maruti")
print(c1.name)
print(c1.start())
print(c1.color)


## inheritance means accept the properties, attributes and method from the first class  or parents class
# Out:
# maruti
# car start..
# None
# blue

# %% [markdown]
# **Multi-level Inheritance**

# %%
class Car():


  @staticmethod
  def start():
    print("car start..")

  @staticmethod
  def stop():
    print("car stoped.")


class ToyotaCar(Car):

  def __init__(self,brand):
    self.brand = brand


class Fortuner(ToyotaCar):

  def __init__(self,type):
    self.type = type


car1 = Fortuner("diesel")
print(car1.type)
print(car1.start())
# Out:
# diesel
# car start..
# None

# %% [markdown]
# **Multiple Inheritance**

# %%
class A:
  varA = "welcome to the class A"

class B:
  varB = "welcome to the class B"

class C(A,B):
  varC = "welcome to the class C"

c1 = C()
print(c1.varC)
print(c1.varA)
print(c1.varB)
# Out:
# welcome to the class C
# welcome to the class A
# welcome to the class B

# %% [markdown]
# **Super method:
#        super() method is used to access metods of the parent class**

# %%
class Car():

  def __init__(self,type):
    self.type = type


  @staticmethod
  def start():
    print("car start..")

  @staticmethod
  def stop():
    print("car stoped.")


class ToyotaCar(Car):

  def __init__(self,name,type):
    super().__init__(type)
    self.name = name
    super().start()


car1 = ToyotaCar("fortuner","diesel")
print(car1.name)
print(car1.type)
# Out:
# fortuner
# diesel

# %% [markdown]
# **Class method:
#                A class method is bound to the class and receives the class as an implicit first argument**

# %% [markdown]
# **Note:
#          static method can not access or modify class state and generally for utility**

# %%
class Person:
  name = "anonymous"

  @classmethod
  def changename(cls,name): ## CLASS METHOD CANGE THE CLASS ATTRIBUTES MEANS CHANGE THE NAME ,
    cls.name =name          ##  NAMEBECAUSE NAME IS ATTRIBUTES

p1 = Person()
p1.changename("ranjesh")
print(Person.name)
print(p1.name)
# Out:
# ranjesh
# ranjesh

# %% [markdown]
# **Polymorphism: Operator Overloading**

# %%
## polymorphims : when the same operator is allowed to have different meaning according to the context
print(1+3) # 4
print("ranjesh"+"arjun") # concatenate
print([1,2,3]+[4,5,6]) # merge

## here + operetor used in different 2 case like int , string , list, but work is same of + operator
# Out:
# 4
# ranjesharjun
# [1, 2, 3, 4, 5, 6]

# %%
## understand the operator overloading with a example


class Complex:
  def __init__(self,real,img):
    self.real = real
    self.img = img

  def showNumber(self):
      print(self.real,"i +",self.img,"j")

  def __add__(self,num2): ## dender function
    newreal = self.real + num2.real
    newimg = self.img + num2.img
    return Complex(newreal,newimg)


  def __sub__(self,num2): ## dender function
    newreal = self.real - num2.real
    newimg = self.img - num2.img
    return Complex(newreal,newimg)


num1 = Complex(1,2)
num1.showNumber()
num2 = Complex(3,4)
num2.showNumber()

num3 = num1 + num2
num3.showNumber()

num4 = num1 - num2
num4.showNumber()
# Out:
# 1 i + 2 j
# 3 i + 4 j
# 4 i + 6 j
# -2 i + -2 j

# %% [markdown]
# # Let's Practice

# %% [markdown]
# **Define a Circle class to create a circle with radius r using the constructor.
#   Define a Area() method of the class which calculate the area of the circle.
#   Define a Parimeter() method of the class which allows you to calculate the perimeter of the circle.**

# %%
class Circle:
  def __init__(self,radius):
    self.radius = radius

  def area (self):
    return (22/7) * self.radius**2

  def perimeter(self):
    return 2* (22/7) * self.radius

c1 = Circle(21)

print(c1.area())
print(c1.perimeter())
# Out:
# 1386.0
# 132.0

# %%
class Employee:
  def __init__(self, role, department, salary):
    self.role = role
    self.department = department
    self.salary = salary

  def showDetails(self):
    print("Role:", self.role)
    print("Department:", self.department)
    print("Salary:", self.salary)

class Engineer(Employee):
  def __init__(self, name , age):
    self.name = name
    self.age = age
    super().__init__("Engineer", "IT", "20000")

eng1 = Engineer("ranjesh",23)
eng1.showDetails()
# Out:
# Role: Engineer
# Department: IT
# Salary: 20000
